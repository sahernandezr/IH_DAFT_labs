# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Lab | Feature engineering
#
# - In this lab, you will use `learningSet.csv` file which you have already cloned in the previous activities.
#
# ### Instructions
#
# Here we will work on cleaning some of the other columns in the dataset using the techniques that we used before in the lessons.

# %%
data = pd.read_csv('../../../sols-ca-da23/Week-7/data_7.01_activities/files_for_activities/learningSet.csv/learning_set.csv')
# Out:
# C:\Users\OMEN\AppData\Local\Temp\ipykernel_47348\3048969513.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('../../../sols-ca-da23/Week-7/data_7.01_activities/files_for_activities/learningSet.csv/learning_set.csv')

# %%
data.shape
# Out:
# (95412, 481)

# %%
pd.set_option('display.max_columns', None)
pd.set_option("display.max_rows", None)

# %%
data.dtypes
# Out:
# ODATEDW       int64
# OSOURCE      object
# TCODE         int64
# STATE        object
# ZIP          object
# MAILCODE     object
# PVASTATE     object
# DOB           int64
# NOEXCH       object
# RECINHSE     object
# RECP3        object
# RECPGVG      object
# RECSWEEP     object
# MDMAUD       object
# DOMAIN       object
# CLUSTER      object
# AGE         float64
# AGEFLAG      object
# HOMEOWNR     object
# CHILD03      object
# CHILD07      object
# CHILD12      object
# CHILD18      object
# NUMCHLD     float64
# INCOME      float64
# GENDER       object
# WEALTH1     float64
# HIT           int64
# MBCRAFT     float64
# MBGARDEN    float64
# MBBOOKS     float64
# MBCOLECT    float64
# MAGFAML     float64
# MAGFEM      float64
# MAGMALE     float64
# PUBGARDN    float64
# PUBCULIN    float64
# PUBHLTH     float64
# PUBDOITY    float64
# PUBNEWFN    float64
# PUBPHOTO    float64
# PUBOPP      float64
# DATASRCE     object
# MALEMILI      int64
# MALEVET       int64
# ...

# %%
numeric.dtypes
# Out:
# ODATEDW       int64
# TCODE         int64
# DOB           int64
# AGE         float64
# NUMCHLD     float64
# INCOME      float64
# WEALTH1     float64
# HIT           int64
# MBCRAFT     float64
# MBGARDEN    float64
# MBBOOKS     float64
# MBCOLECT    float64
# MAGFAML     float64
# MAGFEM      float64
# MAGMALE     float64
# PUBGARDN    float64
# PUBCULIN    float64
# PUBHLTH     float64
# PUBDOITY    float64
# PUBNEWFN    float64
# PUBPHOTO    float64
# PUBOPP      float64
# MALEMILI      int64
# MALEVET       int64
# VIETVETS      int64
# WWIIVETS      int64
# LOCALGOV      int64
# STATEGOV      int64
# FEDGOV        int64
# WEALTH2     float64
# GEOCODE     float64
# POP901        int64
# POP902        int64
# POP903        int64
# POP90C1       int64
# POP90C2       int64
# POP90C3       int64
# POP90C4       int64
# POP90C5       int64
# ETH1          int64
# ETH2          int64
# ETH3          int64
# ETH4          int64
# ETH5          int64
# ETH6          int64
# ...

# %% [markdown]
# - Check for null values in the numerical columns.

# %%
# Out:
# RAMNT_5     0.999906
# RDATE_5     0.999906
# RDATE_3     0.997464
# RAMNT_3     0.997464
# RDATE_4     0.997055
# RAMNT_4     0.997055
# RAMNT_6     0.991867
# RDATE_6     0.991867
# RDATE_15    0.923888
# RAMNT_15    0.923888
# RDATE_23    0.917631
# RAMNT_23    0.917631
# RDATE_20    0.917327
# RAMNT_20    0.917327
# RDATE_7     0.906773
# RAMNT_7     0.906773
# RDATE_17    0.901469
# RAMNT_17    0.901469
# RAMNT_21    0.900296
# RDATE_21    0.900296
# RDATE_10    0.890360
# RAMNT_10    0.890360
# RAMNT_13    0.871609
# RDATE_13    0.871609
# NUMCHLD     0.870184
# RDATE_11    0.845512
# RAMNT_11    0.845512
# GEOCODE     0.840230
# RAMNT_19    0.833595
# RDATE_19    0.833595
# RDATE_9     0.824613
# RAMNT_9     0.824613
# RDATE_24    0.814090
# RAMNT_24    0.814090
# RAMNT_18    0.792710
# RDATE_18    0.792710
# RDATE_22    0.781233
# RAMNT_22    0.781233
# RAMNT_8     0.774955
# RDATE_8     0.774955
# RAMNT_14    0.755618
# RDATE_14    0.755618
# RAMNT_12    0.730642
# ...

# %% [markdown]
# - Use appropriate methods to clean the columns `GEOCODE2`, `WEALTH1`, `ADI`, `DMA`,and `MSA`.
# - Use appropriate EDA (Exploratory Data Analysis) technique where ever necessary.

# %% [markdown]
# From variables_description.md:
#
# `GEOCODE` | Geo Cluster Code indicating the level geography at which a record matches the census data. A nominal or symbolic field. <br /> Blank=No code has been assigned or did not match at any level.
#
# `WEALTH1` | Wealth Rating
#
# `ADI` | ADI Code - Area Deprivation Index. It allows for rankings of neighborhoods by socioeconomic disadvantage in a region of interest (e.g. at the state or national level). It includes factors for the theoretical domains of income, education, employment, and housing quality. It can be used to inform health delivery and policy, especially for the most disadvantaged neighborhood groups. [source](https://www.neighborhoodatlas.medicine.wisc.edu/)
#
# `DMA` | DMA Code - Designated Market Area regions are the geographic areas in the United States in which local television viewing is measured by The Nielsen Company. [source](https://markets.nielsen.com/us/en/contact-us/intl-campaigns/dma-maps/#:~:text=DMA%20(Designated%20Market%20Area)%20regions,geographic%20areas%20within%20their%20business.)
#
# `MSA` | MSA Code - Metropolitan Statistical Area. An MSA consists of one or more counties that contain a city of 50,000 or. more inhabitants, or contain a Census Bureau-defined urbanized area (UA) and have a total population of at least 100,000 (75,000 in New England). [source](https://www2.census.gov/geo/pdfs/reference/GARM/Ch13GARM.pdf)

# %%
#GEOCODE
data['GEOCODE'].value_counts(dropna=False)
#84% of this column is null, we should drop it
# Out:
# NaN     80168
# 12.0     3914
# 3.0      3327
# 14.0     2017
# 5.0      1918
# 4.0      1622
# 2.0      1408
# 1.0      1038
# Name: GEOCODE, dtype: int64

# %%
#WEALTH1
data['WEALTH1'].isnull().sum()/data.shape[0]
#46% of this column is null, we could drop it
# Out:
# 0.4688299165723389

# %%
#if we don0t want to drop it, we could fill it with the mode
data['WEALTH1'].mode()
# Out:
# 0    9.0
# Name: WEALTH1, dtype: float64

# %%
data['ADI'].isnull().sum()/data.shape[0]
# Out:
# 0.0

# %%
data['DMA'].isnull().sum()/data.shape[0]
# Out:
# 0.0

# %%
data['MSA'].isnull().sum()/data.shape[0]
# Out:
# 0.0
